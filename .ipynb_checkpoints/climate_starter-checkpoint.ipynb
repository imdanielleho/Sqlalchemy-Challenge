# %%
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd

# %%
import datetime as dt

# %% [markdown]
# # Reflect Tables into SQLAlchemy ORM

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func, desc

# %%
engine = create_engine("sqlite:///Resources/hawaii.sqlite")

# %%
# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

# %%
# We can view all of the classes that automap found
Base.classes.keys()
# Out:
# ['measurement', 'station']

# %%
# Save references to each table
Measurement = Base.classes.measurement
Station = Base.classes.station

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %% [markdown]
# # Exploratory Climate Analysis

# %% [markdown]
# ## Precipitation Analysis

# %%
#Last data point in the database
end_query_date = session.query(Measurement.date).order_by(Measurement.date.desc()).first()
print("End Date:",end_query_date)
# Out:
# End Date: ('2017-08-23',)

# %%
 # Calculate the date 1 year ago from the last data point in the database
start_query_date = dt.date(2017, 8, 23) - dt.timedelta(days=365)
print("Start Date: ", start_query_date)
# Out:
# Start Date:  2016-08-23

# %%
# Perform a query to retrieve the data and precipitation scores
climate_data = session.query(Measurement.date, Measurement.prcp).\
filter(Measurement.date >= start_query_date).all()
climate_data
# Out:
# [('2016-08-23', 0.0),
#  ('2016-08-24', 0.08),
#  ('2016-08-25', 0.08),
#  ('2016-08-26', 0.0),
#  ('2016-08-27', 0.0),
#  ('2016-08-28', 0.01),
#  ('2016-08-29', 0.0),
#  ('2016-08-30', 0.0),
#  ('2016-08-31', 0.13),
#  ('2016-09-01', 0.0),
#  ('2016-09-02', 0.0),
#  ('2016-09-03', 0.0),
#  ('2016-09-04', 0.03),
#  ('2016-09-05', None),
#  ('2016-09-06', None),
#  ('2016-09-07', 0.05),
#  ('2016-09-08', 0.0),
#  ('2016-09-09', 0.03),
#  ('2016-09-10', 0.0),
#  ('2016-09-11', 0.05),
#  ('2016-09-12', 0.0),
#  ('2016-09-13', 0.02),
#  ('2016-09-14', 1.32),
#  ('2016-09-15', 0.42),
#  ('2016-09-16', 0.06),
#  ('2016-09-17', 0.05),
#  ('2016-09-18', 0.0),
#  ('2016-09-19', 0.0),
#  ('2016-09-20', 0.0),
#  ('2016-09-21', 0.0),
#  ('2016-09-22', 0.02),
#  ('2016-09-23', 0.0),
#  ('2016-09-24', 0.0),
#  ('2016-09-25', 0.0),
#  ('2016-09-26', 0.06),
#  ('2016-09-27', 0.02),
#  ('2016-09-28', 0.0),
#  ('2016-09-29', 0.0),
#  ('2016-09-30', 0.0),
#  ('2016-10-01', 0.0),
# ...

# %%
#Save the query results as a Pandas DataFrame and set the index to the date column
df = pd.DataFrame(climate_data)
df.set_index('date')
df.sort_values(by=['date'], inplace=True, ascending=True)
df.head()
# Out:
#             date  prcp
# 0     2016-08-23  0.00
# 1009  2016-08-23   NaN
# 1529  2016-08-23  1.79
# 704   2016-08-23  0.05
# 361   2016-08-23  0.15

# %%
df.plot('date', 'prcp')
plt.xlabel("date")
plt.legend(["precipitation"], loc='upper center')
plt.xticks([])
plt.savefig('precipitation')
plt.show()

# %% [markdown]
# ![precipitation](Images/precipitation.png)

# %%
# Use Pandas to calcualte the summary statistics for the precipitation data
df.describe()
# Out:
#               prcp
# count  2021.000000
# mean      0.177279
# std       0.461190
# min       0.000000
# 25%       0.000000
# 50%       0.020000
# 75%       0.130000
# max       6.700000

# %% [markdown]
# ![describe](Images/describe.png)

# %% [markdown]
# ## Station Analysis

# %%
# Design a query to show how many stations are available in this dataset?
session.query(Measurement.station).distinct().count()
# Out:
# 9

# %%
first_row = session.query(Measurement).first()
first_row.__dict__
# Out:
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState at 0x117a64150>,
#  'station': 'USC00519397',
#  'prcp': 0.08,
#  'tobs': 65.0,
#  'date': '2010-01-01',
#  'id': 1}

# %%
# List the stations and the counts in descending order.
station_count = session.query(Measurement.station, func.count(Measurement.station)).group_by(Measurement.station).order_by(desc(func.count(Measurement.station))).all()
station_count
# Out:
# [('USC00519281', 2772),
#  ('USC00519397', 2724),
#  ('USC00513117', 2709),
#  ('USC00519523', 2669),
#  ('USC00516128', 2612),
#  ('USC00514830', 2202),
#  ('USC00511918', 1979),
#  ('USC00517948', 1372),
#  ('USC00518838', 511)]

# %%
query_station = station_count[0][0]
query_station
# Out:
# 'USC00519281'

# %%
# Using the station id from the previous query, calculate the lowest temperature recorded, 
# highest temperature recorded, and average temperature of the most active station?
session.query(func.min(Measurement.tobs),func.max(Measurement.tobs),func.avg(Measurement.tobs)).\
filter(Measurement.station == query_station).all()
# Out:
# [(54.0, 85.0, 71.66378066378067)]

# %%
# Choose the station with the highest number of temperature observations.
# Query the last 12 months of temperature observation data for this station and plot the results as a histogram
temp_data = session.query(Measurement.station, Measurement.tobs).\
            filter(Measurement.station == query_station).\
            filter(Measurement.date >= start_query_date).all()
temp_data
# Out:
# [('USC00519281', 77.0),
#  ('USC00519281', 77.0),
#  ('USC00519281', 80.0),
#  ('USC00519281', 80.0),
#  ('USC00519281', 75.0),
#  ('USC00519281', 73.0),
#  ('USC00519281', 78.0),
#  ('USC00519281', 77.0),
#  ('USC00519281', 78.0),
#  ('USC00519281', 80.0),
#  ('USC00519281', 80.0),
#  ('USC00519281', 78.0),
#  ('USC00519281', 78.0),
#  ('USC00519281', 78.0),
#  ('USC00519281', 73.0),
#  ('USC00519281', 74.0),
#  ('USC00519281', 80.0),
#  ('USC00519281', 79.0),
#  ('USC00519281', 77.0),
#  ('USC00519281', 80.0),
#  ('USC00519281', 76.0),
#  ('USC00519281', 79.0),
#  ('USC00519281', 75.0),
#  ('USC00519281', 79.0),
#  ('USC00519281', 78.0),
#  ('USC00519281', 79.0),
#  ('USC00519281', 78.0),
#  ('USC00519281', 78.0),
#  ('USC00519281', 76.0),
#  ('USC00519281', 74.0),
#  ('USC00519281', 77.0),
#  ('USC00519281', 78.0),
#  ('USC00519281', 79.0),
#  ('USC00519281', 79.0),
#  ('USC00519281', 77.0),
#  ('USC00519281', 80.0),
#  ('USC00519281', 78.0),
#  ('USC00519281', 78.0),
# ...

# %%
temp_df = pd.DataFrame(temp_data, columns=['station', 'tobs'])
# temp_df.set_index('station',inplace=True)
temp_df.head()
# Out:
#        station  tobs
# 0  USC00519281  77.0
# 1  USC00519281  77.0
# 2  USC00519281  80.0
# 3  USC00519281  80.0
# 4  USC00519281  75.0

# %%
temp_df.plot.hist(bins=12)
plt.tight_layout()
plt.savefig('station-histogram')
plt.show()

# %% [markdown]
# ![precipitation](Images/station-histogram.png)

# %% [markdown]
# ## Temperature Analysis I

# %%
#Identify the average temperature in June at all stations across all available years in the dataset. 
# Do the same for December temperature.
from sqlalchemy import extract

june_temp = session.query(func.avg(Measurement.tobs)).filter(extract('month',Measurement.date)==6).all()
june_temp 

dec_temp = session.query(func.avg(Measurement.tobs)).filter(extract('month',Measurement.date)==12).all()
dec_temp

print(june_temp, dec_temp)
# Out:
# [(74.94411764705882,)] [(71.04152933421226,)]

# %%
from scipy import stats
stats.ttest_ind(june_temp, dec_temp)
# Out:
# Ttest_indResult(statistic=array([nan]), pvalue=array([nan]))

# %% [markdown]
# ## Temperature Analysis II

# %%
# This function called `calc_temps` will accept start date and end date in the format '%Y-%m-%d' 
# and return the minimum, average, and maximum temperatures for that range of dates
def calc_temps(start_date, end_date):
    """TMIN, TAVG, and TMAX for a list of dates.
    
    Args:
        start_date (string): A date string in the format %Y-%m-%d
        end_date (string): A date string in the format %Y-%m-%d
        
    Returns:
        TMIN, TAVE, and TMAX
    """
    
    return session.query(func.min(Measurement.tobs), func.avg(Measurement.tobs), func.max(Measurement.tobs)).\
        filter(Measurement.date >= start_date).filter(Measurement.date <= end_date).all()

# function usage example
print(calc_temps('2012-02-28', '2012-03-05'))
# Out:
# [(62.0, 69.57142857142857, 74.0)]

# %%
# Use your previous function `calc_temps` to calculate the tmin, tavg, and tmax 
# for your trip using the previous year's data for those same dates.
#Trip dates: 2016/12/23-28
trip_temp = calc_temps('2016-12-23', '2016-12-28')
trip_temp
# Out:
# [(68.0, 72.51351351351352, 78.0)]

# %%
trip_temp_df = pd.DataFrame(trip_temp,columns=['tmin','tave','tmax'])
trip_temp_df.head()
# Out:
#    tmin       tave  tmax
# 0  68.0  72.513514  78.0

# %%
# Plot the results from your previous query as a bar chart. 
# Use "Trip Avg Temp" as your Title
# Use the average temperature for the y value
# Use the peak-to-peak (tmax-tmin) value as the y error bar (yerr)
fig2, ax2 = plt.subplots()
error = [(trip_temp_df['tmax'][0])-(trip_temp_df['tmin'][0])]
ax2 = trip_temp_df['tave'].plot(kind='bar', yerr=error, title ="Trip Avg Temp",figsize=(6,8),
                                alpha=0.5,fontsize=12,color='coral')
ax2.set_ylabel("Temp (F)")
ax2.set_ylim(0, 100)
ax2.get_xaxis().set_ticks([])

fig2.savefig('temperature')

# %%
from sqlalchemy.orm import Query

# %%
# Calculate the total amount of rainfall per weather station for your trip dates using the previous year's matching dates.
# Sort this in descending order by precipitation amount and list the station, name, latitude, longitude, and elevation
# Trip dates: 2016/12/23-28

query = (
        #--FROM AND WHERE
        Query(Station).filter(Measurement.date >= '2016-12-23').filter(Measurement.date <= '2016-12-28')
        .join(Measurement, Measurement.station == Station.station)
        #--SELECT
        .with_entities(Station.station, 
                      Station.name, 
                      Station.latitude, 
                      Station.longitude, 
                      Station.elevation, 
                      func.sum(Measurement.prcp))
        .group_by(Measurement.station)
        .order_by(desc(func.sum(Measurement.prcp)))
        .with_session(session))

# %%
for row in query:
    print(row)
# Out:
# ('USC00516128', 'MANOA LYON ARBO 785.2, HI US', 21.3331, -157.8025, 152.4, 4.05)
# ('USC00519281', 'WAIHEE 837.5, HI US', 21.45167, -157.84888999999998, 32.9, 0.8200000000000001)
# ('USC00513117', 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6, 0.65)
# ('USC00519523', 'WAIMANALO EXPERIMENTAL FARM, HI US', 21.33556, -157.71139, 19.5, 0.2)
# ('USC00514830', 'KUALOA RANCH HEADQUARTERS 886.9, HI US', 21.5213, -157.8374, 7.0, 0.19)
# ('USC00519397', 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0, 0.06)
# ('USC00517948', 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9, None)

# %% [markdown]
# ## Optional Challenge Assignment

# %%
# Create a query that will calculate the daily normals 
# (i.e. the averages for tmin, tmax, and tavg for all historic data matching a specific month and day)

def daily_normals(date):
    """Daily Normals.
    
    Args:
        date (str): A date string in the format '%m-%d'
        
    Returns:
        A list of tuples containing the daily normals, tmin, tavg, and tmax
    
    """
    
    sel = [func.min(Measurement.tobs), func.avg(Measurement.tobs), func.max(Measurement.tobs)]
    return session.query(*sel).filter(func.strftime("%m-%d", Measurement.date) == date).all()
    
daily_normals("01-01")
# Out:
# [(62.0, 69.15384615384616, 77.0)]

# %%
# calculate the daily normals for your trip
# push each tuple of calculations into a list called `normals`
normals = []
# Set the start and end date of the trip
date1 = '2016-12-23'
date2 = '2016-12-28'
# Use the start and end date to create a range of dates
mydates = pd.date_range(date1, date2)

# Stip off the year and save a list of %m-%d strings
date_strings = mydates.strftime('%m-%d')

# Loop through the list of %m-%d strings and calculate the normals for each date
for d in date_strings:
    normals.append(*daily_normals(d))
normals
# Out:
# [(61.0, 70.34693877551021, 78.0),
#  (62.0, 70.0625, 78.0),
#  (60.0, 71.75, 79.0),
#  (63.0, 71.44680851063829, 77.0),
#  (62.0, 71.91666666666667, 79.0),
#  (62.0, 70.52083333333333, 77.0)]

# %%
# Load the previous query results into a Pandas DataFrame and add the `trip_dates` range as the `date` index
normals_df = pd.DataFrame(normals, columns = ['tmin','tavg','tmax'])
normals_df['date'] = mydates
normals_df = normals_df.set_index('date')
normals_df
# Out:
#             tmin       tavg  tmax
# date
# 2016-12-23  61.0  70.346939  78.0
# 2016-12-24  62.0  70.062500  78.0
# 2016-12-25  60.0  71.750000  79.0
# 2016-12-26  63.0  71.446809  77.0
# 2016-12-27  62.0  71.916667  79.0
# 2016-12-28  62.0  70.520833  77.0

# %%
# Plot the daily normals as an area plot with `stacked=False`
normals_df.plot.area(stacked=False, x_compat=True)
plt.xlabel('date')
plt.savefig('daily-normals',bbox_inches = 'tight')
plt.show()
